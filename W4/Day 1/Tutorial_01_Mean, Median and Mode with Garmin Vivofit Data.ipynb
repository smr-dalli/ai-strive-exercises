# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math

# turn of data table rendering
pd.set_option('display.notebook_repr_html', False)
plt.style.use('ggplot')
pd.__version__
# Out:
# '1.0.5'

# %% [markdown]
# ## Data

# %%
# Load 248 days of step data and vivofit goals
data = pd.read_csv('data/garmin-vivofit.csv', index_col='date')

data
# Out:
#             steps  goal  Unnamed: 3  Unnamed: 4
# date
# 4/25/2014    9936  4994         NaN         NaN
# 4/26/2014    7465  5294         NaN         NaN
# 4/27/2014    9437  5610         NaN         NaN
# 4/28/2014    8368  5946         NaN         NaN
# 4/29/2014   10254  6302         NaN         NaN
# ...           ...   ...         ...         ...
# 12/24/2014   4755  6224         NaN         NaN
# 12/25/2014   6748  6150         NaN         NaN
# 12/26/2014   5813  6299         NaN         NaN
# 12/27/2014   4070  6274         NaN         NaN
# 12/28/2014   5644  5960         NaN         NaN
#
# [248 rows x 4 columns]

# %%
data.pop('Unnamed: 4')
data
# Out:
#             steps  goal  Unnamed: 3
# date
# 4/25/2014    9936  4994         NaN
# 4/26/2014    7465  5294         NaN
# 4/27/2014    9437  5610         NaN
# 4/28/2014    8368  5946         NaN
# 4/29/2014   10254  6302         NaN
# ...           ...   ...         ...
# 12/24/2014   4755  6224         NaN
# 12/25/2014   6748  6150         NaN
# 12/26/2014   5813  6299         NaN
# 12/27/2014   4070  6274         NaN
# 12/28/2014   5644  5960         NaN
#
# [248 rows x 3 columns]

# %%
data.pop('Unnamed: 3')
data
# Out:
#             steps  goal
# date
# 4/25/2014    9936  4994
# 4/26/2014    7465  5294
# 4/27/2014    9437  5610
# 4/28/2014    8368  5946
# 4/29/2014   10254  6302
# ...           ...   ...
# 12/24/2014   4755  6224
# 12/25/2014   6748  6150
# 12/26/2014   5813  6299
# 12/27/2014   4070  6274
# 12/28/2014   5644  5960
#
# [248 rows x 2 columns]

# %%
# Plot the steps and goal data
data.steps.plot(kind='area', figsize=(8,5), color='#00A99D', alpha=.5)
data.goal.plot()
plt.ylabel('steps per day')
plt.legend(loc='upper left')
# Out:
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# ## Calculate the mean
# The arithmetic mean is the most commonly used measure of central tendency. The Greek letter $\mu$ (mu) is used to represent the population mean. To calculate the mean, we sum up all values $x_0+x_1+x_n$ and divide it by the number of values $n$.
#
# $$\mu= \frac{1}{n}\sum_{i=0}^n x_i$$

# %%
# Calculate the mean
x, n = 0.0, 0

for number_of_steps in data.steps:
    x += number_of_steps

n = len(data.steps)

mean = x / n
mean
# Out:
# 8059.653225806452

# %%
# We can also let pandas use NumPy's mean function to do the job
data.steps.mean()
# Out:
# 8059.653225806452

# %%
# Or we can call NumPy's mean function ourselves
np.mean(data.steps)
# Out:
# 8059.653225806452

# %%
# Use pandas to get the mean for all columns at ones
data.mean()
# Out:
# steps    8059.653226
# goal     7932.141129
# dtype: float64

# %%
# Plot the mean, togehter with the steps and goal data
data.steps.plot(kind='area', color='#00A99D', alpha=.5, figsize=(8,5))
data.goal.plot(legend=True)
plt.plot([0, len(data.steps)],[mean, mean])
plt.ylabel('steps per day')
plt.text(25, mean-1200, r'$\mu=' + str(int(math.floor(mean))) + '$', fontsize=14)
plt.legend(loc='upper left')
# Out:
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %% [markdown]
# ## Calculate the median
# The median is often a better measure of central tendency when we have extreme outliers. The median is the value in the middle after we sort the data. This is why outliers do not influence the median as much as they do the mean. If the number of observations $n$ is even, we have to take the mean of the two middle values. We calculate for a zero based index.
#
#
# $$n\ is\ odd:\ \ x_{median}=x_{\frac{n-1}{2}}$$
#
# $$n\ is\ even:\ \ x_{median}=\frac{x_\frac{n-2}{2}+x_\frac{n}{2}}{2}$$

# %%
median, n = 0.0, 0

# Get the number of observations
n = len(data.steps)
    
# order the data
ordered_data = data.steps.order()

if n % 2 == 0:
    # n is even
    m1 = ordered_data.ix[(n - 2) / 2]
    m2 = ordered_data.ix[(n / 2)]
    median = (m1 + m2) / 2.0
else:
    # n is odd
    median = ordered_data.ix[(n - 2) / 2.0]

median
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-d32e044b4861> in <module>
#       5
#       6 # order the data
# ----> 7 ordered_data = data.steps.order()
#       8
#       9 if n % 2 == 0:
#
# /opt/venv/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
# Again, we can let pandas use NumPy's median function to do the job
data.steps.median()
# Out:
# 7810.0

# %%
# Or we can call NumPy's median function ourselves
np.median(data.steps)
# Out:
# 7810.0

# %%
# Use pandas to get the median for all columns at ones
data.median()
# Out:
# steps    7810.0
# goal     7619.5
# dtype: float64

# %% [markdown]
# ## Calculate the Mode
# The mode is one or more values which occur most often in the series. This measure of central tendency is especially meaningful when you have a lot of repeated data points (like five-star ratings, day numbers). For the Garmin Vivofit data, however, this holds a problem, because we seldom have the same step count on a particular day. In that case we could categorize our data into range buckets, like 0-1000, 1000-2000 steps, and count the frequencies of the observations in the buckets. Choosing the right bucket size can be tricky, because we can obscure the data or miss the 'real' mode.

# %%
# Let's create a lambda that assigns a bucket of size 1000 steps
# to each of the step count in the data set
bucket_size = 1000
bucket_calculator = lambda x: int(x) / bucket_size * bucket_size

data['bucket'] = data.steps.apply(bucket_calculator)
bucket_min = data.bucket.min()
bucket_max = data.bucket.max()
bins = (bucket_max-bucket_min)/bucket_size

data.bucket.hist(color='#00A99D', alpha=.5, bins=bins, figsize=(8,5))

print('Mode:', data.groupby('bucket').steps.count().idxmax(), \
      'with bucket size', bucket_size)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /opt/venv/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     418         try:
# --> 419             n_equal_bins = operator.index(bins)
#     420         except TypeError as e:
#
# TypeError: 'numpy.float64' object cannot be interpreted as an integer
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-dfaead657adf> in <module>
#       9 bins = (bucket_max-bucket_min)/bucket_size
#      10
# ---> 11 data.bucket.hist(color='#00A99D', alpha=.5, bins=bins, figsize=(8,5))
#      12
#      13 print('Mode:', data.groupby('bucket').steps.count().idxmax(), \
#
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, backend, **kwargs)
#      83         figsize=figsize,
#      84         bins=bins,
# ---> 85         **kwargs,
#      86     )
#      87
#
# /opt/venv/lib/python3.7/site-packages/pandas/plotting/_matplotlib/hist.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#     307         values = self.dropna().values
#     308
# --> 309         ax.hist(values, bins=bins, **kwds)
#     310         ax.grid(grid)
#     311         axes = np.array([ax])
#
# /opt/venv/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/venv/lib/python3.7/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6649             # this will automatically overwrite bins,
#    6650             # so that each histogram uses the same bins
# -> 6651             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6652             tops.append(m)
#    6653         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# /opt/venv/lib/python3.7/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# /opt/venv/lib/python3.7/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     420         except TypeError as e:
#     421             raise TypeError(
# --> 422                 '`bins` must be an integer, a string, or an array') from e
#     423         if n_equal_bins < 1:
#     424             raise ValueError('`bins` must be positive, when an integer')
#
# TypeError: `bins` must be an integer, a string, or an array

# %%
data.steps.mode()
# Out:
# 0     6243
# 1     6532
# 2    11482
# dtype: int64
