# %%
# Start writing code here...
aTuple = (10, 20, 30, 40, 50)
x = aTuple[::-1]
print(x)
# Out:
# (50, 40, 30, 20, 10)

# %%
aTuple = ("Orange", [10, 20, 30], (5, 15, 25))
aTuple[1][1]
# Out:
# 20

# %%
Tuple= (50,)*5
Tuple
# Out:
# (50, 50, 50, 50, 50)

# %%
aTuple = (10, 20, 30, 40)
a,b,c,d = aTuple
print(a)
print(b)
print(c)
print(d)
# Out:
# 10
# 20
# 30
# 40

# %%
tuple1 = (11, 22)
tuple2 = (99, 88)
tuple1,tuple2 = (99, 88),(11, 22)
print('tuple1:',tuple1,'\ntuple2:',tuple2)
# Out:
# tuple1: (99, 88)
# tuple2: (11, 22)

# %%
tuple1 = (11, 22, 33, 44, 55, 66)
tuple2 = tuple1[3:5]
print(tuple2)
# Out:
# (44, 55)

# %%
tuple1 = (11, [22, 33], 44, 55)
tuple1[1][0]  = 222
print(tuple1)
# Out:
# (11, [222, 33], 44, 55)

# %%
tuple1 = (('a', 23),('b', 37),('c', 11), ('d',29))
sorted_tupe = tuple(sorted(list(tuple1),key = lambda x: x[1]))
print(sorted_tupe)
# Out:
# (('c', 11), ('a', 23), ('d', 29), ('b', 37))

# %%
tuple1 = (50, 10, 60, 70, 50)
tuple1.count(50)
# Out:
# 2

# %%
tuple1 = (45, 45, 45, 45)
for i in tuple1:
    if i == tuple1[0]:
        print(True)
    else:
        print(False)
# Out:
# True
# True
# True
# True
