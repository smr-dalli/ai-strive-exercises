# %%
# Start writing code here...
# Out:
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.1)
# WARNING: You are using pip version 20.3.3; however, version 21.0 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
# Collecting lxml
#   Downloading lxml-4.6.2-cp37-cp37m-manylinux1_x86_64.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 17.1 MB/s
# Installing collected packages: lxml
# Successfully installed lxml-4.6.2
# WARNING: You are using pip version 20.3.3; however, version 21.0 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 20.6 MB/s
# Requirement already satisfied: six>=1.9 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1
# WARNING: You are using pip version 20.3.3; however, version 21.0 is available.
# You should consider upgrading via the '/usr/local/bin/python -m pip install --upgrade pip' command.

# %%
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.7/site-packages (21.0)
# Collecting pip
#   Using cached pip-21.0-py3-none-any.whl (1.5 MB)
#   Using cached pip-20.3.4-py2.py3-none-any.whl (1.5 MB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/site-packages (4.6.2)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.7/site-packages (1.1)
# Requirement already satisfied: six>=1.9 in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: webencodings in /shared-libs/python3.7/py-core/lib/python3.7/site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/site-packages (from beautifulsoup4->bs4) (2.1)

# %%
# !/usr/local/bin/python -m pip install --upgrade pip
# !pip install  lxml
# !pip install html5lib
# !pip install bs4
import pandas as pd
import requests

web = requests.get('https://www.infoplease.com/us/postal-information/state-abbreviations-and-state-postal-codes')
dfs = pd.read_html(web.text)
for df in dfs:
    print(df.head())
df1 = dfs[0].describe()
df2 = dfs[1].describe()
print(df1)
print(df2)
# Out:
#   State/District Abbreviation Postal Code
# 0        Alabama         Ala.          AL
# 1         Alaska       Alaska          AK
# 2        Arizona        Ariz.          AZ
# 3       Arkansas         Ark.          AR
# 4     California       Calif.          CA
#         Territory/Associate Abbreviation Postal Code
# 0            American Samoa          NaN          AS
# 1                      Guam         Guam          GU
# 2          Marshall Islands          NaN          MH
# 3                Micronesia          NaN          FM
# 4  Northern Mariana Islands          NaN          MP
#        State/District Abbreviation Postal Code
# count              51           51          51
# unique             51           51          51
# top             Idaho         N.Y.          CA
# freq                1            1           1
#        Territory/Associate Abbreviation Postal Code
# count                    8            2           8
# unique                   8            2           8
# top            Puerto Rico         P.R.          MP
# freq                     1            1           1
