# %%
# Start writing code here...
# !pip install bs4
import requests
from bs4 import BeautifulSoup
import pandas as pd

page =requests.get("https://weather.com/weather/tenday/l/San+Francisco+CA?canonicalCityId=dfdaba8cbe3a4d12a8796e1f7b1ccc7174b4b0a2d5ddb1c8566ae9f154fa638c")
# Print the status code of the response
print(page)
soup =BeautifulSoup(page.content, 'html.parser')

html = list(soup.children)[1]
body = list(html.children)[1]

weather = {}

day_list = []
date_list = []
high_temp_list = []
low_temp_list = []
weather_condition = []
precipation = []
wind_speed = []

#data = body.find_all('details', class_="Disclosure--themeList--uBa5q",index = '0')
for i in range(1,11):
    data = body.find('div', id = f'detailIndex{i}')

    first_value = list(data.children)[0].get_text() + '.12.2020'
    day_and_date = first_value.split()

    day_list.append(day_and_date[0])
    date_list.append(day_and_date[1])

    second_value = list(data.children)[1].get_text()

    high_and_low_temp = second_value.replace('/',' ')
    temperature = high_and_low_temp.split()

    high_temp = temperature[0] 
    high_temp_list.append(high_temp)

    low_temp = temperature[1]
    low_temp_list.append(low_temp)

    third_value = list(data.children)[2].get_text()
    weather_condition.append(third_value)

    fourth_value = list(data.children)[3].get_text()
    precipation.append(fourth_value)

    fifth_value = list(data.children)[4].get_text()
    wind_speed.append(fifth_value)

weather['Day_name'] = day_list
weather['Date'] = date_list
weather['Max Temperature'] = high_temp_list
weather['Min Temperature'] = low_temp_list
weather['Speed of wind']= wind_speed

Dataset = pd.DataFrame(weather)
Dataset
# Out:
# Collecting bs4
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 12.1 MB/s
# Collecting soupsieve>1.2; python_version >= "3.0"
#   Downloading soupsieve-2.0.1-py3-none-any.whl (32 kB)
# Building wheels for collected packages: bs4
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1273 sha256=9220fe166057f84932165f5c9857ef615ebca2449cc148967143de137980d0c5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/0a/9e/ba/20e5bbc1afef3a491f0b3bb74d508f99403aabe76eda2167ca
# Successfully built bs4
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.9.3 bs4-0.0.1 soupsieve-2.0.1
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.
# <Response [200]>
#   Day_name        Date Max Temperature Min Temperature Speed of wind
# 0      Thu  10.12.2020             58°             44°      W 16 mph
# 1      Fri  11.12.2020             56°             48°     WNW 9 mph
# 2      Sat  12.12.2020             57°             50°     SW 11 mph
# 3      Sun  13.12.2020             59°             49°    SSW 16 mph
# 4      Mon  14.12.2020             58°             44°     WNW 9 mph
# 5      Tue  15.12.2020             58°             47°      NE 7 mph
# 6      Wed  16.12.2020             58°             47°     WSW 7 mph
# 7      Thu  17.12.2020             59°             46°      NW 7 mph
# 8      Fri  18.12.2020             58°             46°       N 7 mph
# 9      Sat  19.12.2020             59°             45°     NNE 7 mph
