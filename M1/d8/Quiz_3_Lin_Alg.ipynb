# %% [markdown]
# ## Linear Algebra Quiz #3
#
# ![title](./img/3_0.jpeg)
#
# We strongly suggest working with numpy :)

# %%
#Do your imports here
import numpy as np
import math

# %% [markdown]
# ![title](./img/3_2.png)
# ![title](./img/3_3.png)
# Create a program that can output
#
# - What is the value of element c23​ of Matrix C where C=A x B ?
# - What is the value of element c23​ of Matrix C where C=B x A ?

# %%
# okay numpy is great but... how would you inverse a matrix by hand?

A = np.array([[3,1,2],[-5,4,1],[0,3,-8]])
B = np.array([[0,5,-1],[3,2,-1],[10,0.5,4]])
C = np.cross(A,B)
D = np.cross(B,A)

print("The cross product of A and B:",C)
print()
print("The cross product of A and B:",D)


print("the value of element c23​ of Matrix: ",C[1][2])
print("the value of element d23​ of Matrix: ",D[1][2])
print()
print()

def inv_matrix(A):
    return np.linalg.inv(A)
C = inv_matrix(A)
print("Inverse Matrix of A :",C)
print()

def inverse_matrix(B):
    return np.linalg.inv(B)
D = inverse_matrix(B)
print("Inverse Matrix of B :",D)
# Out:
# The cross product of A and B: [[-11.   3.  15.]
#  [ -6.  -2. -22.]
#  [ 16. -80. -30.]]
#
# The cross product of A and B: [[ 11.  -3. -15.]
#  [  6.   2.  22.]
#  [-16.  80.  30.]]
# the value of element c23​ of Matrix:  -22.0
# the value of element d23​ of Matrix:  22.0
#
#
# Inverse Matrix of A : [[ 0.2        -0.08        0.04      ]
#  [ 0.22857143  0.13714286  0.07428571]
#  [ 0.08571429  0.05142857 -0.09714286]]
#
# Inverse Matrix of B : [[-0.09289617  0.22404372  0.03278689]
#  [ 0.24043716 -0.10928962  0.03278689]
#  [ 0.20218579 -0.54644809  0.16393443]]

# %% [markdown]
# ![title](./img/3_1.png)
# Create a program that can output
#
# - What is the value of the ijth element if i = 2 and j=3?
# - What is the value of the ijth element if i = 3 and j=1?

# %%
# Just answer using code --> easy stuff!

# Harder
# Can you build a matrix solver that can do output the result given n matrices and a sequence of operations such as [add subtract multiply transpose?]
#Some ideas on valid operations: Multiplication Addition Subtraction Inverstion Transposed. 
A = [[3,0.6,4,-3],[-1.3,4,0,8.6],[7,0,-8,0.006]]
B = [[3,-5.76,45,0],[2,-2,1.3,9],[-9,0,0,0]]
C = [[0,1009,-66.7849,90],[0,5,4,-0.07],[-7.7,0,0,0]]
X = np.add(A,B)
D = np.subtract(X,C)
print(D)
print(D[1][2])
print(D[2][0])

#The value of element D31​ gives an error of invalid index to scalar variable
#print(D[3][1])
# Out:
# [[ 6.000000e+00 -1.014160e+03  1.157849e+02 -9.300000e+01]
#  [ 7.000000e-01 -3.000000e+00 -2.700000e+00  1.767000e+01]
#  [ 5.700000e+00  0.000000e+00 -8.000000e+00  6.000000e-03]]
# -2.7
# 5.7

# %% [markdown]
# ![title](./img/3_3.png)
# Create a program that can output
# - How many rows will C have?
# - How many columns will C have?
# - What will be the value of c13​?

# %%
# C will have 1 row and 3 columns
A = [0.6,-15,2,5,98]
B = [[2,2,-4],[9,-14,0],[13,-0.5,44],[1,9,4],[0,0,5]]
A_Transpose = np.transpose(A)
#B_Transpose = np.transpose(B)
c = np.dot(A_Transpose,B)
print(c)
print(c[2])
# Out:
# [-102.8  255.2  595.6]
# 595.6
