# %% [markdown]
# ## **Write your answers directly in the cells on this notebook.**
#
# ### Show the entire process, from the initial fractions to the final result.
# The probability results must be a decimal value between 0.0 and 1.0. Round your number to the third decimal (e.g 0.574).**

# %% [markdown]
# Consider the following boxes (two boxes (red/blue) with two types of balls (green/orange)):
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercise 1: which is the probability of selecting the red box?

# %%
##There are two boxes of color red and blue. The probability of picking of red box is 1/2 and the blue box is 1/2
print("The probability of picking the red box is 1/2")
print(round(1/2,3)
# Out:
# The probability of picking the red box is 1/2
# 0.5

# %% [markdown]
# #### Exercise 2: if you want to run out of balls both boxes at the same time, how often should you select the blue box?

# %%
# If I want to run out of balls in red box having 8 balls, The probability is 8/12
# If I want to run out of balls in blue box having 4 balls, The probability is 4/12
print("Running out of balls by selecting the blue box is 4/12")
print(round(4/12,3))
# Out:
# Running out of balls by selecting the blue box is 4/12
# 0.333

# %% [markdown]
# #### Exercise 3: which is the probability of picking up a green ball if you are using the red box?

# %%
# There are 8 balls in the red box, out of which 2 are green and 6 are orange balls.
print("The probability of picking up a green ball if I am using the red box is 2/8 i.e 1/4 ")
print(round(1/4,3))
# Out:
# The probability of picking up a green ball if I am using the red box is 2/8 i.e 1/4
# 0.25

# %% [markdown]
# #### Exercise 4: which is the probability of picking up an orange ball (any of the boxes)?

# %%
# There are a total of 7 orange balls and 5 green balls in both the boxes
#The probality of picking a orange ball in red box is 6/8
#The probality of picking a orange ball in blue box is 1/4
print("The probality of picking a orange ball in both boxes are 6/8 * 1/4 ")
print(6/8 * 1/4)
# Out:
# The probality of picking a orange ball in both boxes are 6/8 * 1/4
# 0.1875

# %% [markdown]
# #### Optional Exercise 5: given that you picked up a green ball, which is the probability of having selected the red box?

# %%
# No need to use the Bayes Theorem as it has not been explained in class
# There are a total of 5 green balls in both the boxes out of which 2 green balls are in red box.
print("The probability of picking a green ball from the red box is 2/5")
print(round(2/5,3))
# Out:
# The probability of picking a green ball from the red box is 2/5
# 0.4

# %% [markdown]
# #### Optional Exercise 6: I have chosen a ball from a box and I picked up a green one. Which is the probability of having used the blue box?

# %%
# No need to use the Bayes Theorem as it has not been explained in class
# There are a total of 5 green balls in both the boxes out of which 3 green balls are in blue box.
print("The probability of picking a green ball from the blue box is 3/5")
print(round(3/5,3))
# Out:
# The probability of picking a green ball from the blue box is 3/5
# 0.6

# %% [markdown]
# Now consider a standard deck of cards (the one used in Poker):
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercise 7: which is the probability of drawing an Ace?

# %%
# Create function that returns probability percent rounded to three decimal places
# There are 4 Ace's in a deck of 52 cards
def event_probability(event_outcomes, sample_space):
    print("There are 4 Ace's in a deck of 52 cards")
    probability = event_outcomes/sample_space
    return f'The probability of drawing an Ace is {round(probability, 3)}'
event_probability(4,52)
# Out:
# There are 4 Ace's in a deck of 52 cards
# 'The probability of drawing an Ace is 0.077'

# %%
# Using the previously defined function: Determine the probability of drawing an Ace

# %% [markdown]
# #### Exercise 8: which is the probability of drawing a card that is a Heart?

# %%
# Using the previously defined function: Determine the probability of drawing a heart
def event_probability(event_outcomes, sample_space):
    print("There are 13 cards of heart in a deck of 52 cards")
    probability = event_outcomes/sample_space
    return f' The probability of drawing a card that is a heart {round(probability, 3)}'
event_probability(13,52)
# Out:
# There are 13 cards of heart in a deck of 52 cards
# ' The probability of drawing a card that is a heart 0.25'

# %% [markdown]
# #### Exercise 9: which is the probability of drawing a face card (such as Jacks, Queens, or Kings)?

# %%
# Using the previously defined function: Determine the probability of drawing a face card
def event_probability(event_outcomes, sample_space):
    print("There are 4 kings, 4 queens and 4 jacks in a deck of 52 cards")
    probability = event_outcomes/sample_space
    return f' The probability of drawing a face card is {round(probability, 3)}'
event_probability(12,52)
# Out:
# There are 4 kings, 4 queens and 4 jacks in a deck of 52 cards
# ' The probability of drawing a face card is 0.231'

# %% [markdown]
# #### Exercise 10: which is the probability of drawing a face card which is also a Heart?

# %%
# Using the previously defined function: Determine the probability of drawing the jack, queen or king  of hearts
def event_probability(event_outcomes, sample_space):
    print("There is 1 king, 1 queen and 1 jack in hearts")
    probability = event_outcomes/sample_space
    return f'The probability of drawing a face card which is also a heart is {round(probability, 3)}'
event_probability(3,13)
# Out:
# There is 1 king, 1 queen and 1 jack in hearts
# 'The probability of drawing a face card which is also a heart is 0.231'

# %% [markdown]
# #### Exercise 11: which is the probability of drawing an Ace on the second draw, if the first card drawn was a King?

# %%
# Using the previously defined function: Determine the probability of drawing an Ace after drawing a King on the first draw
def event_probability(event_outcomes, sample_space):
    probability = event_outcomes/sample_space
    return round(probability, 3)
print("The probability of drawing a king out of 4 kings in a deck of 52 cards is (4/52) and drawing an ace on the second is (4/51) ")
first_card = event_probability(4,52)
second_card = event_probability(4,51)
C = first_card*second_card

print(f"The probability of drawing an Ace on the second draw, if the first card drawn was a King is {round(C,3)}")
# Out:
# The probability of drawing a king out of 4 kings in a deck of 52 cards is (4/52) and drawing an ace on the second is (4/51)
# The probability of drawing an Ace on the second draw, if the first card drawn was a King is 0.006

# %% [markdown]
# #### Exercise 12: which is the probability of drawing an Ace on the second draw, if the first card drawn was an Ace?

# %%
# Using the previously defined function: Determine the probability of drawing an Ace after drawing an Ace on the first draw
def event_probability(event_outcomes, sample_space):
    probability = event_outcomes/sample_space
    return round(probability, 3)
print("The probability of drawing an Ace out of 4 Ace's in a deck of 52 cards is (4/52) and drawing an ace on the second is (3/51) ")
first_card = event_probability(4,52)
second_card = event_probability(3,51)
C = first_card*second_card

print(f"The probability of drawing an Ace on the second draw, if the first card drawn was a King is {round(C,3)}")
# Out:
# The probability of drawing an Ace out of 4 Ace's in a deck of 52 cards is (4/52) and drawing an ace on the second is (3/51)
# The probability of drawing an Ace on the second draw, if the first card drawn was a King is 0.005

# %% [markdown]
# Now consider the following situation:
#
# You are playing Poker in the [Texas Holdem variant](https://en.wikipedia.org/wiki/Texas_hold_%27em). In case you are not familiar, it is a variant of poker in which each player has two cards and there is a set of community cards to play from.
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercise 13: what is the probability that the next card drawn will be a Diamond card?

# %%
# Sample Space
#cards = 
#player_cards = 
#turn_community_cards = 
#cards = cards - (player_cards + turn_community_cards)

# Outcomes
#diamonds = 13
#diamonds_drawn = 

# In poker, cards that complete a draw are known as "outs"
#outs = 

#Determine river flush probability using the previously defined function
#river_flush_probability = event_probability(outs, cards)
#river_flush_probability

Total_cards= 52
total_diamonds = 13
probability = total_diamonds/Total_cards
print("The probability that the next card drawn will be a Diamond card is",probability)
# Out:
# The probability that the next card drawn will be a Diamond card is 0.25

# %% [markdown]
# Now consider the following situation:
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Exercise 14: which is the probability that with the next card drawn there will be five cards in sequential order?
#
# (Notice that any Eight ( 8, 9, 10, Jack, Queen) or any King (9, 10, Jack, Queen, King) will complete the straight)

# %%
# Sample Space
sample_space_for_8     = 52
sample_space_for_9     = 51
sample_space_for_10    = 50
sample_space_for_jack  = 49
sample_space_for_queen = 48


# Outcomes
outcome_8 = 4
outcome_9 = 4
outcome_10 = 4
outcome_jack = 4
outcome_queen = 4


# Determine river straight probability
probability = round(4/52 * 4/51 * 4/50 * 4/49 * 4/48,6)
print("the probability that with the next card drawn there will be five cards in sequential order is ", probability)
# Out:
# the probability that with the next card drawn there will be five cards in sequential order is  3e-06

# %% [markdown]
# ## Now, we keep playing Texas Holdem
# ![](https://media.giphy.com/media/EQBsWLfdxHW01Y1OHK/giphy.gif)
# ### But looking only at the cards we could have in our hand
# ### (2 possible drawing events, ignore community cards)
# #### Exercise 15: which is the probability of drawing a heart OR drawing a club?

# %%
# Calculate the probability of drawing a heart or a club
# There are 13 hearts and 13 clubs in a deck of 52 cards
# The probability of drawing a heart is 13/52
# The probability of drawing a club is 13/52
print("The probability of drawing a heart OR drawing a club is ", 13/52 + 13/52)
# Out:
# The probability of drawing a heart OR drawing a club is  0.5

# %% [markdown]
# #### Exercise 16: which is the probability of drawing an ace, a king or a queen?

# %%
# Calculate the probability of drawing an ace, king, or a queen
# There are 4 aces, 4 kings and 4 queens in a deck of 52 cards and the respective probabilities are 4/52,4/52, and 4/52
print("The probability of drawing an ace, a king or a queen is ", round(4/52 + 4/52 + 4/52,3))
# Out:
# The probability of drawing an ace, a king or a queen is  0.231

# %% [markdown]
# #### Exercise 17: which is the probability of drawing a heart or an ace?

# %%
# Calculate the probability of drawing a heart or an ace
# There are 4 aces and 13 hearts in a deck of 52 cards and the respective probabilities are 4/52 and 13/52
print("The probability of drawing an ace or a heart is ", round(4/52 + 13/52 ,3))
# Out:
# The probability of drawing an ace or a heart is  0.327

# %% [markdown]
# #### Exercise 18: which is the probability of drawing a red card or drawing a face card?

# %%
# Calculate the probability of drawing a red card or a face card
# There are 26 red cards and 12 face cards in a deck of 52 cards and the respective probabilities are 26/52 and 12/52
print("The probability of drawing a red card or drawing a face card is ", round(26/52 + 12/52 ,3))
# Out:
# The probability of drawing a red card or drawing a face card is  0.731

# %% [markdown]
# #### Exercise 19: which is the probability of drawing an Ace from a deck of cards, replacing it, reshuffling the deck, and drawing another Ace?

# %%
# Sample Space
#The Sample Space is a deck of 52 cards
Sample_Space = 52


# Outcomes
# There are two outcomes of drawing an ace 
outcome1 = 4
outcome2 = 4


# Probability of one ace
Probability_1= round(outcome1/Sample_Space,3)
print("The probability of drawing an Ace from a deck of cards is ",Probability_1 )


# Probability of two consecutive independent aces 
Probability = round(outcome1/Sample_Space,3) * round(outcome2/Sample_Space,3)
print("Probability of two consecutive independent aces ",round(Probability,5))
# Out:
# The probability of drawing an Ace from a deck of cards is  0.077
# Probability of two consecutive independent aces  0.00593

# %% [markdown]
# #### Exercise 20: which is the probability of being dealt two Aces (drawing one Ace after the other starting with a full deck)?

# %%
# Sample Space first draw
sample_space = 52

# Outcomes first draw
outcome1 = 4



# Probability of ace on first draw
Probability_1 = outcome1/sample_space
print("Probability of ace on first draw is ", round(Probability_1,5))


# Sample Space second draw
sample_space_new = 51


# Outcomes second draw
outcome2 = 3


# Probability of ace on second draw after ace on first
Probability_2 = (outcome2/sample_space_new)
print("Probability of ace on second draw after ace on first ",round(Probability_2,5))


# Probability of two consecutive aces (dependent)
overall_probability = (Probability_1 * Probability_2)
print("Probability of two consecutive aces (dependent) is ",round(overall_probability,5))
# Out:
# Probability of ace on first draw is  0.07692
# Probability of ace on second draw after ace on first  0.05882
# Probability of two consecutive aces (dependent) is  0.00452

# %% [markdown]
# ### Permutations and combinations

# %% [markdown]
# #### Exercise 22: How many different 5-letter arrangements are there of the letters in the word moose?

# %%
# word : MOOSE (5 letters with two repeating letters)
#Permutations: 5!/2!
print(5*4*3*2*1/2*1)
# Out:
# 60.0

# %% [markdown]
# #### Exercise 23: How many different seven-letter arrangements of the letters in the word HEXAGON can be made if each letter is used only once?

# %%
# Word  = HEXAGON (7 letters words are all are unique)
# It can be arranged in 7! Ways
print(7*6*5*4*3*2*1)
# Out:
# 5040

# %% [markdown]
# #### Exercise 24: Two cards are drawn at random from a standard deck of cards, without replacement. Find the probability of drawing an 8 and a queen in that order.

# %%
# When two cards are drawn at random then the first card drawn from 52 cards and the second card is from 51 cards
# There are 4 "8's" in a deck of 52 cards and 4 queens in the same deck.
# Probability of drawing a 8 card is 4/52 
# Probability of drawing a 8 card is 4/51
print("The probability of drawing an 8 and a queen in that order is 16/2652 i.e ",round(4/52*4/51,5) )
# Out:
# The probability of drawing an 8 and a queen in that order is 16/2652 i.e  0.00603
