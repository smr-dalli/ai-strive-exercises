# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("/work/Thriller, 20th Century Fox _US_ _Sorted by Number of Votes Descending_ - IMDb.csv")
print(df.head(5))
fig = px.bar(df,x = 'Director',y = 'Votes',title = 'Positive reviews of a movie ')
fig1 = px.bar(df,x = 'Title',y = 'Gross',title = 'Budget for a movie') 
fig.show()
fig1.show()
# Out:
#                         Title    Year certificate     Time  \
# 0          Mad Max: Fury Road  (2015)          15  120 min
# 1                   Gone Girl  (2014)          18  149 min
# 2                    Die Hard  (1988)          18  132 min
# 3                  Black Swan  (2010)          15  108 min
# 4  X-Men: Days of Future Past  (2014)         12A  132 min
#
#                                      genre  Rating  \
# 0  \nAction, Adventure, Sci-Fi                 8.1
# 1   \nDrama, Mystery, Thriller                 8.1
# 2           \nAction, Thriller                 8.2
# 3            \nDrama, Thriller                 8.0
# 4  \nAction, Adventure, Sci-Fi                 7.9
#
#                                            Score  \
# 0  \n90        \n        Metascore\n
# 1  \n79        \n        Metascore\n
# 2  \n72        \n        Metascore\n
# 3  \n79        \n        Metascore\n
# 4  \n75        \n        Metascore\n
#
# ...
